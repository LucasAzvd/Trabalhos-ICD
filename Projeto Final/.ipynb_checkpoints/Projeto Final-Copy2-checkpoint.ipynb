# %% [markdown]
#     Aluno    : Lucas Araujo Azevedo
#     Matrícula: 2017104188
#
# # Temas: Diabetes
#
# Trabalho irá utilizar a base de dados do [Kagle sobre diabetes](https://www.kaggle.com/uciml/pima-indians-diabetes-database) e focará em tentar resolver as seguintes perguntas:
# + A grossura da pele do triceps tem alguma relação com a chance de ter diabetes?
# + A gravidez gera uma tendência a ter diabetes?
# + Existe relação entre glicose, insulina, pressão sanguinea?

# %%
from IPython.display import HTML
import random

def hide_toggle(for_next=False):
    this_cell = """$('div.cell.code_cell.rendered.selected')"""
    next_cell = this_cell + '.next()'

    toggle_text = 'Toggle show/hide'  # text shown on toggle link
    target_cell = this_cell  # target cell to control with toggle
    js_hide_current = ''  # bit of JS to permanently hide code in current cell (only when toggling next cell)

    if for_next:
        target_cell = next_cell
        toggle_text += ' next cell'
        js_hide_current = this_cell + '.find("div.input").hide();'

    js_f_name = 'code_toggle_{}'.format(str(random.randint(1,2**64)))

    html = """
        <script>
            function {f_name}() {{
                {cell_selector}.find('div.input').toggle();
            }}

            {js_hide_current}
        </script>

        <a href="javascript:{f_name}()">{toggle_text}</a>
    """.format(
        f_name=js_f_name,
        cell_selector=target_cell,
        js_hide_current=js_hide_current, 
        toggle_text=toggle_text
    )

    return HTML(html)

import warnings
warnings.filterwarnings('ignore')

hide_toggle()
# Out:
#         <script>
#             function code_toggle_14463210463429666023() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_14463210463429666023()">Toggle show/hide</a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('diabetes.csv')
hide_toggle()
# Out:
#         <script>
#             function code_toggle_2908986390744960649() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_2908986390744960649()">Toggle show/hide</a>

# %%
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
# Ajustando as colunas
df.columns = ['quant_gravides', 'glicose', 'pressao_sangue', 'pele_triceps', 
              'insulina', 'imc', 'prob_diabetes_familia', 'idade', 'diabetico']
print("Ajustando as colunas")
hide_toggle()
# Out:
# Ajustando as colunas
#         <script>
#             function code_toggle_1425536821265894072() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_1425536821265894072()">Toggle show/hide</a>

# %%
df.head(2)
# Out:
#    quant_gravides  glicose  pressao_sangue  pele_triceps  insulina   imc  \
# 0               6      148              72            35         0  33.6
# 1               1       85              66            29         0  26.6
#
#    prob_diabetes_familia  idade  diabetico
# 0                  0.627     50          1
# 1                  0.351     31          0

# %% [markdown]
# Tendo ajustado o DataFrame, partiremos para a análise de dados, realizando verificações simples sobre balanceamento e buscando alguma relação entre os dados.
# Partindo de uma visão mais simples, dividindo o nosso DataFrame em dois grupos principais: os que são diabéticos e os que não são, para comparar alguns números e buscar algum gráfico normal.

# %%
df_diabetico = df[df['diabetico'] == 1]
df_saudavel = df[df['diabetico'] == 0]
hide_toggle()
# Out:
#         <script>
#             function code_toggle_1436877752770153564() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_1436877752770153564()">Toggle show/hide</a>

# %%
print("df_diabetico.mean() - df_saudavel.mean()\n")
print(df_diabetico.mean() - df_saudavel.mean())
hide_toggle()
# Out:
# df_diabetico.mean() - df_saudavel.mean()
#
# quant_gravides            1.567672
# glicose                  31.277463
# pressao_sangue            2.640627
# pele_triceps              2.500179
# insulina                 31.543821
# imc                       4.838337
# prob_diabetes_familia     0.120766
# idade                     5.877164
# diabetico                 1.000000
# dtype: float64
#         <script>
#             function code_toggle_5336765459914737759() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_5336765459914737759()">Toggle show/hide</a>

# %% [markdown]
# Observamos que a insulina e a glicose possuem uma média maior para pessoas diabéticas. Esse fato já era esperado,
#  para verificação se não existe possíveis outliers, compararemos a mediana:

# %%
print("Saudáveis")
print(f"Média glicose Saudaveis   : {np.mean(df_saudavel['glicose'])}")
print(f"Mediana glicose Saudaveis : {np.median(df_saudavel['glicose'])}")
print(f"Média insulina Saudaveis  : {np.mean(df_saudavel['insulina'])}")
print(f"Mediana insulina Saudaveis: {np.median(df_saudavel['insulina'])}")
print("\nDiabéticos")
print(f"Média glicose Diabéticos   : {np.mean(df_diabetico['glicose'])}")
print(f"Mediana glicose Diabéticos : {np.median(df_diabetico['glicose'])}")
print(f"Média insulina Diabéticos  : {np.mean(df_diabetico['insulina'])}")
print(f"Mediana insulina Diabéticos: {np.median(df_diabetico['insulina'])}")

print('''
Vemos que Em geral não existe outliers (apenas no caso da insulina em diabéticos)
''')
hide_toggle()
# Out:
# Saudáveis
# Média glicose Saudaveis   : 109.98
# Mediana glicose Saudaveis : 107.0
# Média insulina Saudaveis  : 68.792
# Mediana insulina Saudaveis: 39.0
#
# Diabéticos
# Média glicose Diabéticos   : 141.25746268656715
# Mediana glicose Diabéticos : 140.0
# Média insulina Diabéticos  : 100.33582089552239
# Mediana insulina Diabéticos: 0.0
#
# Vemos que Em geral não existe outliers (apenas no caso da insulina em diabéticos)
#         <script>
#             function code_toggle_15431032998367853829() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_15431032998367853829()">Toggle show/hide</a>

# %% [markdown]
# Vamos realizar uma verificação de correlação, para maior simplicidade e melhor visualização, plotaremos um gráfico de calor com as correlações

# %%
sns.heatmap(df.corr(), annot=True, vmin=0, vmax=1)

plt.show()
hide_toggle()
# Out:
#         <script>
#             function code_toggle_9266179452804276817() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_9266179452804276817()">Toggle show/hide</a>

# %% [markdown]
# Vemos que não existe uma correlação forte entre nenhum dos dados, mas isso não significa que não podemos utiliza-los
# Vamos explorar mais profundamente o data frame seccionando apenas para as partes importantes para nossa pergunta.
# Sabemos que insulina é faz parte tratamento da diabetes, então utilizaremos sempre essa variável como target para comparação dos outros dados

# %% [markdown]
# ### Primeira pergunta "A grossura da pele do triceps tem alguma relação com a chance de ter diabetes?"

# %%
sns.scatterplot(x="pele_triceps", y="insulina", hue="diabetico",
                sizes=(10, 200), data=df, alpha=0.5)
plt.xlabel("Pele Tríceps")
plt.ylabel("Insulina",)
plt.legend()
plt.show()

df_1 = df[['pele_triceps', 'insulina', 'diabetico']]
hide_toggle()
# Out:
#         <script>
#             function code_toggle_12209037192900949193() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_12209037192900949193()">Toggle show/hide</a>

# %% [markdown]
# Não existe correlação aparente a partir do gráfico de dispersão

# %% [markdown]
# Tentaremos aplicar um modelo de regressão para um teste se realmente não são relacionados e não geram nenhum resultado plausível

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression()

# %%
from sklearn.model_selection  import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn import metrics

x = df_1.iloc[:,0:-1]
y = df_1.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.33, random_state=42)

model_lr.fit(x_train, y_train)

y_pred = model_lr.predict(x_test)

print(f"Acurácia: {accuracy_score(y_test, y_pred)}")
print("\n\nDistribuições dos acertos\n")
print(classification_report(y_test, y_pred))

hide_toggle()
# Out:
# Acurácia: 0.6614173228346457
#
#
# Distribuições dos acertos
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.98      0.79       168
#            1       0.50      0.05      0.09        86
#
#     accuracy                           0.66       254
#    macro avg       0.58      0.51      0.44       254
# weighted avg       0.61      0.66      0.55       254
#         <script>
#             function code_toggle_17860758651738791908() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_17860758651738791908()">Toggle show/hide</a>

# %% [markdown]
# Utilizando um modelo de regressão observamos que a pele do triceps não é um fator totalmente determinante para a ocorrência do diabetes.

# %% [markdown]
# ### Segunda pergunta "A gravidez gera uma tendência a ter diabetes?"

# %%
df_2 = df[['quant_gravides', 'insulina', 'diabetico']]
hide_toggle()
# Out:
#         <script>
#             function code_toggle_16786018592490588006() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_16786018592490588006()">Toggle show/hide</a>

# %%
ax = sns.scatterplot(x="quant_gravides", y="insulina", hue="diabetico", data=df_2)
hide_toggle()
# Out:
#         <script>
#             function code_toggle_525745560005819546() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_525745560005819546()">Toggle show/hide</a>

# %% [markdown]
# Foi adicionado um ruído, para verificação de possíveis clusteres.

# %%
n = df_2.shape[0]
df_2['quant_gravides'] = df_2['quant_gravides'] + np.random.normal(0, 0.2, size=n)
hide_toggle()
# Out:
#         <script>
#             function code_toggle_11095362225239431984() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_11095362225239431984()">Toggle show/hide</a>

# %%
ax = sns.scatterplot(x="quant_gravides", y="insulina", hue="diabetico", data=df_2)
hide_toggle()
# Out:
#         <script>
#             function code_toggle_5352452225399070989() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_5352452225399070989()">Toggle show/hide</a>

# %% [markdown]
# Vemos que não existem clusteres e nem uma correção forte entre os eixos

# %% [markdown]
# Realizando o mesmo teste aplicado a pele do tríceps

# %%
model_lr = LogisticRegression()

df_2 = df[['quant_gravides', 'insulina', 'diabetico']]
x = df_2.iloc[:,0:-1]
y = df_2.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.33, random_state=42)

model_lr.fit(x_train, y_train)

y_pred = model_lr.predict(x_test)

print(f"Acurácia: {accuracy_score(y_test, y_pred)}")
print("\n\nDistribuições dos acertos\n")
print(classification_report(y_test, y_pred))
hide_toggle()
# Out:
# Acurácia: 0.6850393700787402
#
#
# Distribuições dos acertos
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.92      0.79       168
#            1       0.59      0.23      0.33        86
#
#     accuracy                           0.69       254
#    macro avg       0.64      0.57      0.56       254
# weighted avg       0.66      0.69      0.64       254
#         <script>
#             function code_toggle_15673195510913190379() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_15673195510913190379()">Toggle show/hide</a>

# %% [markdown]
# Obtemos uma performace melhor do que relacionando a pele do tríceps. Porém não temos uma acurácia grande.

# %% [markdown]
# ### Terceira pergunta "Existe relação entre glicose, insulina, pressão sanguinea?"

# %%
df_3 = df[['glicose', 'pressao_sangue', 'insulina']]
hide_toggle()
# Out:
#         <script>
#             function code_toggle_3852046926073349532() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_3852046926073349532()">Toggle show/hide</a>

# %%
print(df_3.corr())
hide_toggle()
# Out:
#                  glicose  pressao_sangue  insulina
# glicose         1.000000        0.152590  0.331357
# pressao_sangue  0.152590        1.000000  0.088933
# insulina        0.331357        0.088933  1.000000
#         <script>
#             function code_toggle_17151775881456568312() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_17151775881456568312()">Toggle show/hide</a>

# %%
sns.pairplot(df_3)
plt.show()
hide_toggle()
# Out:
#         <script>
#             function code_toggle_1255373159774502234() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_1255373159774502234()">Toggle show/hide</a>

# %% [markdown]
# Segundo o [Portal da Educação](https://www.portaleducacao.com.br/conteudo/artigos/enfermagem/funcao-da-insulina-no-corpo/34860):
# >A insulina promove o transporte de glicose para essas células de modo idêntico ao das outras células do corpo
#
# Vemos que a influência existe e é biológica, porém no nosso dataframe ela não é forte e não é um fator que influência a pressão sanguínea da pessoa

# %% [markdown]
# ## Tentando obter melhores resultados com o DataFrame completo

# %%
print("Proporção dentro do Dataframe:")
print(df['diabetico'].value_counts())

hide_toggle()
# Out:
# Proporção dentro do Dataframe:
# 0    500
# 1    268
# Name: diabetico, dtype: int64
#         <script>
#             function code_toggle_17148878874254722026() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_17148878874254722026()">Toggle show/hide</a>

# %% [markdown]
# Nosso Dataframe está desbalanceado e ao aplicar algum modelo de Machine Learning ele provavelmente irá ficar enviesado. Para evitar isso, balancearemos o DataFrame.

# %%
print(df[df['diabetico'] == 0].sample(frac=0.53)['diabetico'].value_counts())
hide_toggle()
# Out:
# 0    265
# Name: diabetico, dtype: int64
#         <script>
#             function code_toggle_8316725496498040115() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_8316725496498040115()">Toggle show/hide</a>

# %%
df_0 = df[df['diabetico'] == 0].sample(frac=0.53)
df_1 = df[df['diabetico'] == 1]

df_balanced = pd.concat([df_0,df_1])
print(df_balanced['diabetico'].value_counts())
hide_toggle()
# Out:
# 1    268
# 0    265
# Name: diabetico, dtype: int64
#         <script>
#             function code_toggle_2322390603737554809() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_2322390603737554809()">Toggle show/hide</a>

# %% [markdown]
# Separando os dados de treino e teste.
# Embaralhamos os dados dentro do Dataframe para que ao treinar o modelo tenha um pouco mais de dificuldade.

# %%
from sklearn.utils import shuffle

df_balanced = shuffle(df_balanced, random_state=42)

x = df_balanced.iloc[:,0:-1]
y = df_balanced.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.33, random_state=42)
hide_toggle()
# Out:
#         <script>
#             function code_toggle_10610068843539794665() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_10610068843539794665()">Toggle show/hide</a>

# %%
model_lr = LogisticRegression()

model_lr.fit(x_train, y_train)
hide_toggle()
# Out:
#         <script>
#             function code_toggle_11517060741600683778() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_11517060741600683778()">Toggle show/hide</a>

# %%
y_pred = model_lr.predict(x_test)

print(f"Acurácia: {accuracy_score(y_test, y_pred)}")
print("\n\nDistribuições dos acertos\n")
print(classification_report(y_test, y_pred))
print("Verificando a matriz de confusão")
print(metrics.confusion_matrix(y_test, y_pred))
hide_toggle()
# Out:
# Acurácia: 0.7556818181818182
#
#
# Distribuições dos acertos
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.71      0.77        98
#            1       0.69      0.81      0.75        78
#
#     accuracy                           0.76       176
#    macro avg       0.76      0.76      0.76       176
# weighted avg       0.77      0.76      0.76       176
#
# Verificando a matriz de confusão
# [[70 28]
#  [15 63]]
#         <script>
#             function code_toggle_3409275795381122596() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_3409275795381122596()">Toggle show/hide</a>

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(random_state=42)

model_rf.fit(x_train, y_train)
hide_toggle()
# Out:
#         <script>
#             function code_toggle_14806450047962379094() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_14806450047962379094()">Toggle show/hide</a>

# %%
predict_rf = model_rf.predict(x_test)

print(f"Acurácia: {accuracy_score(y_test, predict_rf)}")
print("\n\nDistribuições dos acertos\n")
print(classification_report(y_test, predict_rf))
print("Verificando a matriz de confusão")
print(metrics.confusion_matrix(y_test, predict_rf))
hide_toggle()
# Out:
# Acurácia: 0.7159090909090909
#
#
# Distribuições dos acertos
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.69      0.73        98
#            1       0.66      0.74      0.70        78
#
#     accuracy                           0.72       176
#    macro avg       0.72      0.72      0.71       176
# weighted avg       0.72      0.72      0.72       176
#
# Verificando a matriz de confusão
# [[68 30]
#  [20 58]]
#         <script>
#             function code_toggle_1365418652845176020() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_1365418652845176020()">Toggle show/hide</a>

# %% [markdown]
# Temos o RandomForest com melhor desempenho, iremos testar o modelo dentro de todos os dados para ter uma acurácia geral final

# %%
x_geral = df.iloc[:,0:-1]
y_geral = df.iloc[:,-1]

predict_geral = model_rf.predict(x_geral)

print(f"Acurácia: {accuracy_score(y_geral, predict_geral)}")
print("\n\nDistribuições dos acertos\n")
print(classification_report(y_geral, predict_geral))
print("Verificando a matriz de confusão")
print(metrics.confusion_matrix(y_geral, predict_geral))
hide_toggle()
# Out:
# Acurácia: 0.8385416666666666
#
#
# Distribuições dos acertos
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87       500
#            1       0.71      0.90      0.80       268
#
#     accuracy                           0.84       768
#    macro avg       0.83      0.85      0.83       768
# weighted avg       0.86      0.84      0.84       768
#
# Verificando a matriz de confusão
# [[403  97]
#  [ 27 241]]
#         <script>
#             function code_toggle_15334005486822201625() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_15334005486822201625()">Toggle show/hide</a>

# %% [markdown]
# Aplicando o modelo geral, obtemos uma acurácia de 84%!
